# %% [markdown]
# # Koschei Sentinel v0.6 — QLoRA training
#
# Use a GPU runtime. Place the private `koschei-sentinel` repository in `/content/koschei-sentinel` without putting GitHub or Hugging Face tokens inside this notebook.

# %%
from pathlib import Path

REPO = Path('/content/koschei-sentinel')
assert REPO.is_dir(), 'Upload or securely clone the private repository first.'
# %cd /content/koschei-sentinel

# %%
# %pip install -q -e '.[dev,training]'

# %% [markdown]
# Copy `configs/training/qlora.colab.example.json`, then replace the model identifier, full 40-character model commit SHA, dataset release, run ID, and output directory. Run the network-free plan before execution.

# %%
CONFIG = 'configs/training/qlora.colab.example.json'
# !sentinel-train --config {CONFIG} --plan-output build/training/colab.plan.json

# %%
# Execute only after inspecting the plan and confirming the pinned model revision.
# !sentinel-train --config {CONFIG} --plan-output build/training/colab.plan.json --execute
